# %%
import os
os.environ["OPENAI_API_KEY"] = "test"

# %%
from langchain.vectorstores import Milvus
from langchain.embeddings import OpenAIEmbeddings

# %% [markdown]
# ### Testing Milvus

# %%
vector_db = Milvus(
        collection_name="interview-data",
        embedding_function=OpenAIEmbeddings(),
        connection_args={"host": "127.0.0.1", "port": "19530"},
    )
# Out:
# Failed to create new connection using: c182f3c5e5d74184a28397ae56d72092
# ---------------------------------------------------------------------------
# FutureTimeoutError                        Traceback (most recent call last)
# File ~/migpt/venv/lib/python3.10/site-packages/pymilvus/client/grpc_handler.py:131, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     130 try:
# --> 131     grpc.channel_ready_future(self._channel).result(timeout=timeout)
#     132     self._setup_identifier_interceptor(self._user)
#
# File ~/migpt/venv/lib/python3.10/site-packages/grpc/_utilities.py:151, in _ChannelReadyFuture.result(self, timeout)
#     150 def result(self, timeout: Optional[float] = None) -> None:
# --> 151     self._block(timeout)
#
# File ~/migpt/venv/lib/python3.10/site-packages/grpc/_utilities.py:97, in _ChannelReadyFuture._block(self, timeout)
#      96 if remaining < 0:
# ---> 97     raise grpc.FutureTimeoutError()
#      98 else:
#
# FutureTimeoutError:
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 vector_db = Milvus(
#       2         collection_name="interview-data",
#       3         embedding_function=OpenAIEmbeddings(),
#       4         connection_args={"host": "127.0.0.1", "port": "19530"},
#       5     )
#
# File ~/migpt/venv/lib/python3.10/site-packages/langchain/vectorstores/milvus.py:150, in Milvus.__init__(self, embedding_function, collection_name, connection_args, consistency_level, index_params, search_params, drop_old)
#     148 if connection_args is None:
#     149     connection_args = DEFAULT_MILVUS_CONNECTION
# --> 150 self.alias = self._create_connection_alias(connection_args)
#     151 self.col: Optional[Collection] = None
#     153 # Grab the existing collection if it exists
#
# File ~/migpt/venv/lib/python3.10/site-packages/langchain/vectorstores/milvus.py:221, in Milvus._create_connection_alias(self, connection_args)
#     219 except MilvusException as e:
#     220     logger.error("Failed to create new connection using: %s", alias)
# --> 221     raise e
#
# File ~/migpt/venv/lib/python3.10/site-packages/langchain/vectorstores/milvus.py:216, in Milvus._create_connection_alias(self, connection_args)
#     214 alias = uuid4().hex
#     215 try:
# --> 216     connections.connect(alias=alias, **connection_args)
#     217     logger.debug("Created new connection using: %s", alias)
#     218     return alias
#
# File ~/migpt/venv/lib/python3.10/site-packages/pymilvus/orm/connections.py:354, in Connections.connect(self, alias, user, password, db_name, token, **kwargs)
#     351         if parsed_uri.scheme == "https":
#     352             kwargs["secure"] = True
# --> 354     connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     355     return
#     357 # 2nd Priority, connection configs from env
#
# File ~/migpt/venv/lib/python3.10/site-packages/pymilvus/orm/connections.py:302, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     299 t = kwargs.get("timeout")
#     300 timeout = t if isinstance(t, (int, float)) else Config.MILVUS_CONN_TIMEOUT
# --> 302 gh._wait_for_channel_ready(timeout=timeout)
#     303 kwargs.pop("password")
#     304 kwargs.pop("token", None)
#
# File ~/migpt/venv/lib/python3.10/site-packages/pymilvus/client/grpc_handler.py:134, in GrpcHandler._wait_for_channel_ready(self, timeout)
#     132     self._setup_identifier_interceptor(self._user)
#     133 except grpc.FutureTimeoutError as e:
# --> 134     raise MilvusException(
#     135         code=Status.CONNECT_FAILED,
#     136         message=f"Fail connecting to server on {self._address}. Timeout",
#     137     ) from e
#     138 except Exception as e:
#     139     raise e from e
#
# MilvusException: <MilvusException: (code=2, message=Fail connecting to server on 127.0.0.1:19530. Timeout)>
